# %%
import pandas as pd

# %%
df = pd.read_excel("/content/customer_shopping_behavior.xlsx")

# %%
df.head()
# Out:
#   Customer ID\tAge\tGender\tItem Purchased\tCategory\tPurchase Amount (USD)\tLocation\tSize\tColor\tSeason\tReview Rating\tSubscription Status\tShipping Type\tDiscount Applied\tPromo Code Used\tPrevious Purchases\tPayment Method\tFrequency of Purchases
# 0  1\t55\tMale\tBlouse\tClothing\t53\tKentucky\tL...
# 1  2\t19\tMale\tSweater\tClothing\t64\tMaine\tL\t...
# 2  3\t50\tMale\tJeans\tClothing\t73\tMassachusett...
# 3  4\t21\tMale\tSandals\tFootwear\t90\tRhode Isla...
# 4  5\t45\tMale\tBlouse\tClothing\t49\tOregon\tM\t...

# %%
df.tail()
# Out:
#      Customer ID\tAge\tGender\tItem Purchased\tCategory\tPurchase Amount (USD)\tLocation\tSize\tColor\tSeason\tReview Rating\tSubscription Status\tShipping Type\tDiscount Applied\tPromo Code Used\tPrevious Purchases\tPayment Method\tFrequency of Purchases
# 3895  3896\t40\tFemale\tHoodie\tClothing\t28\tVirgin...
# 3896  3897\t52\tFemale\tBackpack\tAccessories\t49\tI...
# 3897  3898\t46\tFemale\tBelt\tAccessories\t33\tNew J...
# 3898  3899\t44\tFemale\tShoes\tFootwear\t77\tMinneso...
# 3899  3900\t52\tFemale\tHandbag\tAccessories\t81\tCa...

# %%
len(df)
# Out:
# 3900

# %%
df.shape
# Out:
# (3900, 1)

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# ...

# %%
len(df)
# Out:
# 3900

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.describe(include="all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %% [markdown]
# **  Data Cleaning**

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df['Item Purchased']
# Out:
# 0         Blouse
# 1        Sweater
# 2          Jeans
# 3        Sandals
# 4         Blouse
#           ...
# 3895      Hoodie
# 3896    Backpack
# 3897        Belt
# 3898       Shoes
# 3899     Handbag
# Name: Item Purchased, Length: 3900, dtype: object

# %%
df['Item Purchased'].unique()
# Out:
# array(['Blouse', 'Sweater', 'Jeans', 'Sandals', 'Sneakers', 'Shirt',
#        'Shorts', 'Coat', 'Handbag', 'Shoes', 'Dress', 'Skirt',
#        'Sunglasses', 'Pants', 'Jacket', 'Hoodie', 'Jewelry', 'T-shirt',
#        'Scarf', 'Hat', 'Socks', 'Backpack', 'Belt', 'Boots', 'Gloves'],
#       dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories    [Handbag, Sunglasses, Jewelry, Scarf, Hat, Bac...
# Clothing       [Blouse, Sweater, Jeans, Shirt, Shorts, Dress,...
# Footwear                       [Sandals, Sneakers, Shoes, Boots]
# Outerwear                                         [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessory    [Handbag, Sunglasses, Scarf, Belt]
# Cloth            [Jeans, Shorts, Dress, Hoodie]
# Footwear             [Sandals, Sneakers, Boots]
# Name: Item Purchased, dtype: object

# %%
correct_mapping = {
  "Blouse": "Clothing",
  "Sweater": "Clothing",
  "Jeans": "Clothing",
  "Dress": "Clothing",
  "Shorts": "Clothing",
  "Shirt": "Clothing",
  "Coat": "Outerwear",
  "Pants": "Clothing",
  "T-shirt": "Clothing",
  "Skirt": "Clothing",
  "Hoodie": "Clothing",
  "Socks": "Clothing",

  "Handbag": "Accessories",
  "Sunglasses": "Accessories",
  "Jewelry": "Accessories",
  "Scarf": "Accessories",
  "Hat": "Accessories",
  "Belt": "Accessories",
  "Backpack": "Accessories",
  "Gloves": "Accessories",

  "Sandals": "Footwear",
  "Shoes": "Footwear",
  "Boots": "Footwear",
  "Sneakers": "Footwear",

  "Jacket": "Outerwear"
}

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchased_amount  \
# 0            1   55   Male         Blouse       NaN                53
# 1            2   19   Male        Sweater       NaN                64
# 2            3   50   Male          Jeans     Cloth                73
# 3            4   21   Male        Sandals  Footwear                90
# 4            5   45   Male         Blouse       NaN                49
#
#         location                 size      color  season  review_rating  \
# 0       Kentucky                    L       Gray  Winter            3.1
# 1          Maine                    L     Maroon  Winter            3.1
# 2  Massachusetts                    S     Maroon  Spring            3.1
# 3   Rhode Island  Not Applicable Size     Maroon  Spring            3.5
# 4         Oregon                    M  Turquoise  Spring            2.7
#
#   subscription_status  shipping_type discount_applied promo_code_used  \
# ...

# %%
df['category']=df['item_purchased'].map(correct_mapping)

# %%
df.groupby('category')['item_purchased'].unique()
# Out:
# category
# Accessories                      [Handbag, Sunglasses, Jewelry, Scarf, Hat, Backpack, Belt, Gloves]
# Clothing       [Blouse, Sweater, Jeans, Shirt, Shorts, Dress, Skirt, Pants, Hoodie, T-shirt, Socks]
# Footwear                                                          [Sandals, Sneakers, Shoes, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: item_purchased, dtype: object

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# item_purchased            0
# category                  0
# purchased_amount          0
# location                  0
# size                      0
# color                     0
# season                    0
# review_rating             0
# subscription_status       0
# shipping_type             0
# discount_applied          0
# promo_code_used           0
# previous_purchases        0
# payment_method            0
# frequency_of_purchases    0
# dtype: int64

# %% [markdown]
# **Treating null values **

# %%
df['size'].unique()
# Out:
# array(['L', 'S', 'Not Applicable Size', 'M', 'Free Size', 'XL'],
#       dtype=object)

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessory    [M, S, L, XL]
# Cloth        [S, L, M, XL]
# Footwear     [M, S, XL, L]
# Name: Size, dtype: object

# %%
df.groupby('item_purchased')['size'].unique()
# Out:
# item_purchased
# Backpack              [XL, M, L, S]
# Belt                    [Free Size]
# Blouse                [L, M, S, XL]
# Boots         [Not Applicable Size]
# Coat                  [L, M, S, XL]
# Dress                 [M, XL, S, L]
# Gloves                [L, S, M, XL]
# Handbag                 [Free Size]
# Hat                   [S, L, M, XL]
# Hoodie                [M, S, L, XL]
# Jacket                [M, XL, L, S]
# Jeans                 [S, XL, M, L]
# Jewelry               [M, L, XL, S]
# Pants                 [M, XL, L, S]
# Sandals       [Not Applicable Size]
# Scarf                   [Free Size]
# Shirt                 [M, L, S, XL]
# Shoes                 [L, M, S, XL]
# Shorts                [L, S, M, XL]
# Skirt                 [M, XL, S, L]
# Sneakers      [Not Applicable Size]
# Socks                 [XL, L, S, M]
# Sunglasses              [Free Size]
# Sweater               [L, S, M, XL]
# T-shirt               [L, M, XL, S]
# Name: size, dtype: object

# %%
# Treating null values ot replacing all valies electronic
df.loc[df['category']=='Electronic','Size']='Not Aplicable'

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessory    [M, S, L, XL]
# Cloth        [S, L, M, XL]
# Footwear     [M, S, XL, L]
# Name: Size, dtype: object

# %%
# Treating null values or eplacing all values in the Accessory category
df.loc[df['category']=='Accessories','size']='Free Size'

# %%
df.groupby('category')['size'].unique()
# Out:
# category
# Accessories                           [Free Size]
# Clothing                            [L, S, M, XL]
# Footwear       [Not Applicable Size, L, M, S, XL]
# Outerwear                           [L, M, S, XL]
# Name: size, dtype: object

# %%
df.loc[df['category']=='Footwear','size']='Not Applicable Size'

# %%
df.groupby('category')['size'].unique()
# Out:
# category
# Accessories              [Free Size]
# Clothing               [L, S, M, XL]
# Footwear       [Not Applicable Size]
# Outerwear              [L, M, S, XL]
# Name: size, dtype: object

# %% [markdown]
# **Review Rating**

# %%
df.head(20)
# Out:
#     customer_id  age gender item_purchased     category  purchased_amount  \
# 0             1   55   Male         Blouse     Clothing                53
# 1             2   19   Male        Sweater     Clothing                64
# 2             3   50   Male          Jeans     Clothing                73
# 3             4   21   Male        Sandals     Footwear                90
# 4             5   45   Male         Blouse     Clothing                49
# 5             6   46   Male       Sneakers     Footwear                20
# 6             7   63   Male          Shirt     Clothing                85
# 7             8   27   Male         Shorts     Clothing                34
# 8             9   26   Male           Coat    Outerwear                97
# 9            10   57   Male        Handbag  Accessories                31
# 10           11   53   Male          Shoes     Footwear                34
# 11           12   30   Male         Shorts     Clothing                68
# ...

# %%
# Mean of review rating

# %%
df['Review Rating'].mean()
# Out:
# np.float64(3.750064716541548)

# %%
# Mean of review rating
df['Review Rating'].median()
# Out:
# 3.8

# %%
df['Review Rating'].mode()
# Out:
# 0    3.4
# Name: Review Rating, dtype: float64

# %%
df.groupby('category')['Review Rating'].mean()
# Out:
# Category
# Accessory    3.749042
# Cloth        3.710980
# Footwear     3.808277
# Name: Review Rating, dtype: float64

# %%
df.groupby('Item Purchased')['Review Rating'].mean()
# Out:
# Item Purchased
# Backpack      3.752448
# Belt          3.763522
# Blouse        3.680473
# Boots         3.818881
# Coat          3.727673
# Dress         3.750000
# Gloves        3.862774
# Handbag       3.775163
# Hat           3.801307
# Hoodie        3.716779
# Jacket        3.763190
# Jeans         3.648387
# Jewelry       3.758824
# Pants         3.720833
# Sandals       3.844654
# Scarf         3.705806
# Shirt         3.622024
# Shoes         3.749660
# Shorts        3.714194
# Skirt         3.785350
# Sneakers      3.757931
# Socks         3.755063
# Sunglasses    3.751572
# Sweater       3.760870
# T-shirt       3.779310
# Name: Review Rating, dtype: float64

# %%
df.groupby('Item Purchased')['Review Rating'].transform('mean')
# Out:
# 0       3.680473
# 1       3.760870
# 2       3.648387
# 3       3.844654
# 4       3.680473
# 5       3.757931
# 6       3.622024
# 7       3.714194
# 8       3.727673
# 9       3.775163
# 10      3.749660
# 11      3.714194
# 12      3.727673
# 13      3.750000
# 14      3.727673
# 15      3.785350
# 16      3.751572
# 17      3.750000
# 18      3.760870
# 19      3.720833
# 20      3.720833
# 21      3.720833
# 22      3.720833
# 23      3.720833
# 24      3.763190
# 25      3.716779
# 26      3.758824
# 27      3.714194
# 28      3.775163
# 29      3.750000
# 30      3.758824
# 31      3.750000
# 32      3.763190
# 33      3.720833
# 34      3.779310
# 35      3.680473
# 36      3.779310
# 37      3.648387
# 38      3.750000
# 39      3.720833
# 40      3.775163
# 41      3.705806
# 42      3.727673
# 43      3.705806
# 44      3.801307
# 45      3.755063
# 46      3.622024
# 47      3.758824
# 48      3.622024
# 49      3.716779
# 50      3.680473
# 51      3.785350
# ...

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchased_amount  \
# 0            1   55   Male         Blouse  Clothing                53
# 1            2   19   Male        Sweater  Clothing                64
# 2            3   50   Male          Jeans  Clothing                73
# 3            4   21   Male        Sandals  Footwear                90
# 4            5   45   Male         Blouse  Clothing                49
#
#         location                 size      color  season  review_rating  \
# 0       Kentucky                    L       Gray  Winter            3.1
# 1          Maine                    L     Maroon  Winter            3.1
# 2  Massachusetts                    S     Maroon  Spring            3.1
# 3   Rhode Island  Not Applicable Size     Maroon  Spring            3.5
# 4         Oregon                    M  Turquoise  Spring            2.7
#
#   subscription_status  shipping_type discount_applied promo_code_used  \
# ...

# %% [markdown]
# **Previous Purchase**

# %%
df['previous_purchases']= df['previous_purchases'].fillna

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# item_purchased            0
# category                  0
# purchased_amount          0
# location                  0
# size                      0
# color                     0
# season                    0
# review_rating             0
# subscription_status       0
# shipping_type             0
# discount_applied          0
# promo_code_used           0
# previous_purchases        0
# payment_method            0
# frequency_of_purchases    0
# dtype: int64

# %%
df['Purchase Amount (USD)']= df['Purchase Amount (USD)'].fillna(df.groupby('Item Purchased')['Purchase Amount (USD)'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                  2221
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating               37
# Subscription Status          0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases       0
# dtype: int64

# %%
df['Review Rating']= df['Review Rating'].fillna(df.groupby('Item Purchased')['Review Rating'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                       0
# Item Purchased               0
# Category                  2221
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating                0
# Subscription Status          0
# Shipping Type                0
# Discount Applied             0
# Promo Code Used              0
# Previous Purchases           0
# Payment Method               0
# Frequency of Purchases       0
# dtype: int64

# %% [markdown]
# **Checking Duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases]
# Index: []

# %%
df.count()
# Out:
# customer_id               3900
# age                       3900
# gender                    3900
# item_purchased            3900
# category                  3900
# purchased_amount          3900
# location                  3900
# size                      3900
# color                     3900
# season                    3900
# review_rating             3900
# subscription_status       3900
# shipping_type             3900
# discount_applied          3900
# promo_code_used           3900
# previous_purchases        3900
# payment_method            3900
# frequency_of_purchases    3900
# dtype: int64

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchased_amount  \
# 0            1   55   Male         Blouse  Clothing                53
# 1            2   19   Male        Sweater  Clothing                64
# 2            3   50   Male          Jeans  Clothing                73
# 3            4   21   Male        Sandals  Footwear                90
# 4            5   45   Male         Blouse  Clothing                49
#
#         location                 size      color  season  review_rating  \
# 0       Kentucky                    L       Gray  Winter            3.1
# 1          Maine                    L     Maroon  Winter            3.1
# 2  Massachusetts                    S     Maroon  Spring            3.1
# 3   Rhode Island  Not Applicable Size     Maroon  Spring            3.5
# 4         Oregon                    M  Turquoise  Spring            2.7
#
#   subscription_status  shipping_type discount_applied promo_code_used  \
# ...

# %% [markdown]
# **Renaming the headers**

# %%
df.columns = [
    'customer_id', 'age', 'gender', 'item_purchased', 'category',
    'purchase_amount_usd', 'location', 'size', 'color', 'season',
    'review_rating', 'subscription_status', 'shipping_type', 'discount_applied',
    'promo_code_used', 'previous_purchases', 'payment_method',
    'frequency_of_purchases'
]

df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_usd', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df=df.rename(columns={"purchase_amount_usd":"purchased_amount"})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchased_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     customer_id  age gender item_purchased     category  purchased_amount  \
# 0             1   55   Male         Blouse     Clothing                53
# 1             2   19   Male        Sweater     Clothing                64
# 2             3   50   Male          Jeans     Clothing                73
# 3             4   21   Male        Sandals     Footwear                90
# 4             5   45   Male         Blouse     Clothing                49
# 5             6   46   Male       Sneakers     Footwear                20
# 6             7   63   Male          Shirt     Clothing                85
# 7             8   27   Male         Shorts     Clothing                34
# 8             9   26   Male           Coat    Outerwear                97
# 9            10   57   Male        Handbag  Accessories                31
# 10           11   53   Male          Shoes     Footwear                34
# 11           12   30   Male         Shorts     Clothing                68
# ...

# %% [markdown]
# **Connecting to SQL Server**

# %%
# Save your final DataFrame as CSV in Colab
df.to_csv('customer_behavior_analysis.csv', index=False)
print("✅ CSV file created!")
# Out:
# ✅ CSV file created!

# %%
from google.colab import files

# This will download the file to your PC
files.download('customer_behavior_analysis.csv')
print("✅ File downloaded to your PC!")
# Out:
# ✅ File downloaded to your PC!
